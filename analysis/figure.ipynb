# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 1000
# 忽略警告訊息
import warnings

warnings.filterwarnings('ignore')
import matplotlib.cm as cm
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
# 設定 data_path
dir_data = './data/'

# 讀取檔案
f_app = os.path.join(dir_data, 'quoteDailyChange.csv')
print('Path of read in data: %s' % (f_app))
data = pd.read_csv(f_app)
data["Multiply"]= ""
data.head(30)
# Out:
# Path of read in data: ./data/quoteDailyChange.csv
#           date  stockChange  dollarChange Multiply
# 0   1985/11/21     0.000000      0.000000
# 1   1985/11/22     0.054615     -0.729069
# 2   1985/11/25    -0.580587      0.007897
# 3   1985/11/26     0.159716     -0.371131
# 4   1985/11/27     0.931876     -0.007926
# 5   1985/11/29    -0.182678     -0.776791
# 6    1985/12/2    -0.845818      0.319540
# 7    1985/12/3     0.199538      0.366300
# 8    1985/12/4     1.677783     -0.476039
# 9    1985/12/5    -0.171371      0.063776
# 10   1985/12/6    -0.436531      0.446144
# 11   1985/12/9     0.620718      0.348985
# 12  1985/12/10     0.068543      0.403098
# 13  1985/12/11     0.939380      0.047233
# 14  1985/12/12     0.203576     -0.401290
# 15  1985/12/13     1.552753      0.134302
# 16  1985/12/16     0.990760     -0.528600
# 17  1985/12/17    -0.646170      0.118972
# 18  1985/12/18    -0.398764      0.712984
# 19  1985/12/19     0.100093     -0.401164
# ...

# %%
print(data.iloc[1,2]) #close[1,1]*[1,2]
print(data.iloc[1,3])
for i in range(0,8336):
    data.iloc[i,3] = (data.iloc[i,1]*data.iloc[i,2])
print(data.tail(5))
# Out:
# -0.7290686735653864
#
#             date  stockChange  dollarChange    Multiply
# 8331  2018/12/24    -2.711225     -0.464465     1.25927
# 8332  2018/12/26     4.959374      0.584332     2.89792
# 8333  2018/12/27     0.856268     -0.587151   -0.502759
# 8334  2018/12/28    -0.124158     -0.037500  0.00465589
# 8335  2018/12/31     0.849248     -0.239671    -0.20354

# %%
# import matplotlib.dates as mdates
# fig = data['Multiply'].iloc[:100].plot(kind='bar', figsize=(500, 5), title='USDollarIndex-S&P500',ylim=(-10,10) ,color=np.where(data['Multiply'] >= 0, 'g', 'r'),
# rot=90).axhline(0, color='black', linewidth=1).get_figure()

# %%
# fig.savefig('test15.png')

# %%
# import matplotlib.ticker as ticker
# start, end = ax.get_xlim()
# ax.xaxis.set_ticks(np.arange(start, end, 0.712123))
# ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))

# %%
#fig.savefig('test13.png')

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.ticker as ticker

# fig, ax = plt.subplots()
# ax.plot(data['date'],data['Multiply'],Multiply'],color=np.where(data['Multiply'] >= 0, 'g', 'r'))
# start, end = ax.get_xlim()
# ax.xaxis.set_ticks(np.arange(start, end, 0.712123))
# ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import matplotlib.ticker as plticker

# x = [0,5,9,10,15]
# y = [0,1,2,3,4]
# fig, ax = plt.subplots()
# ax.plot(x,y)
# loc = plticker.MultipleLocator(base=2.0) # this locator puts ticks at regular intervals
# ax.xaxis.set_major_locator(loc)
# plt.show()

# %%
# import matplotlib.dates as mdates
# fig = data.plot(x='date',y='Multiply',kind='bar', figsize=(750, 5), title='USDollarIndex-S&P500',ylim=(-10,10) ,color=np.where(data['Multiply'] >= 0, 'g', 'r'),
# rot=90).axhline(0, color='black', linewidth=1).get_figure()

# %%
#fig.savefig('test17.png')

# %%
# data['date'] = pd.to_datetime(data['date'])
# ax = fig.gca()
# ax.xaxis.set_major_locator(mdates.MonthLocator(interval=4))
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))

# %%
# fig.savefig('test17.png')

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots()
fig = data.iloc[:100].plot(x='date',y='Multiply',kind='bar', figsize=(750, 5), title='USDollarIndex-S&P500',ylim=(-10,10) ,color=np.where(data['Multiply'] >= 0, 'g', 'r'),
rot=90).axhline(0, color='black', linewidth=1)

# %%
fig=fig.get_figure()
fig.savefig('test17.png')
